# %% [markdown]
# # Chapter 1: World of Datasets
#
# ## Author: Audrey Marthin
#
# ### Sources:
# - https://pandas.pydata.org/docs/
# - https://ourworldindata.org/
# - Professor Wirfs-Brock's Class Code Demo
# - Audrey's projects
#
# Date: Saturday, December 9

# %% [markdown]
# ### Part 1: Intro to Pandas
# Pandas is a Python library that helps work with structured data. Pandas provides accessible data structures like DataFrame, which is basically a table in a database or kind of like an Excel spreadsheet.

# %%
# Import packages 
import numpy as np
import pandas as pd

# %%
# Load the data in the form of a CSV file

# Import "private-investment-in-artificial-intelligence-by-focus-area.csv" and save it as a dataframe
# Note: make sure CSV file is in the correct file path
df_ai_investment = pd.read_csv("data/private-investment-in-artificial-intelligence-by-focus-area.csv")

# %%
# Examine dataframe
df_ai_investment
# Out:
#               Entity  Code  Year       World  \
# 0        AI ventures   NaN  2017   705626292
# 1        AI ventures   NaN  2018  1539250299
# 2        AI ventures   NaN  2019  1212544984
# 3        AI ventures   NaN  2020  1545821073
# 4        AI ventures   NaN  2021  2379370717
# ..               ...   ...   ...         ...
# 155  Venture capital   NaN  2018   217600809
# 156  Venture capital   NaN  2019   106903067
# 157  Venture capital   NaN  2020   179347432
# 158  Venture capital   NaN  2021   225784599
# 159  Venture capital   NaN  2022    14814431
#
#      European Union and United Kingdom      China  United States
# 0                             34720055  233168581      404163765
# 1                             30321937  591347599      857474812
# 2                             15388467   93042361      962517568
# 3                              5170265   91954563     1358836062
# 4                           1013359242  258977775      923024967
# ..                                 ...        ...            ...
# 155                                  0  107910146      109690663
# 156                           26497349          0       28617137
# 157                                  0  124590452        4502008
# 158                                  0          0       60011724
# 159                           14814431          0              0
#
# [160 rows x 7 columns]

# %% [markdown]
# We can observe there are 7 columns and 160 rows, each representing private investments in artificial intelligence

# %%
# Displays the header
df_ai_investment.head()
# Out:
#         Entity  Code  Year       World  European Union and United Kingdom  \
# 0  AI ventures   NaN  2017   705626292                           34720055
# 1  AI ventures   NaN  2018  1539250299                           30321937
# 2  AI ventures   NaN  2019  1212544984                           15388467
# 3  AI ventures   NaN  2020  1545821073                            5170265
# 4  AI ventures   NaN  2021  2379370717                         1013359242
#
#        China  United States
# 0  233168581      404163765
# 1  591347599      857474812
# 2   93042361      962517568
# 3   91954563     1358836062
# 4  258977775      923024967

# %%
# Displays the first 10 rows
df_ai_investment.head(10)
# Out:
#                     Entity  Code  Year       World  \
# 0              AI ventures   NaN  2017   705626292
# 1              AI ventures   NaN  2018  1539250299
# 2              AI ventures   NaN  2019  1212544984
# 3              AI ventures   NaN  2020  1545821073
# 4              AI ventures   NaN  2021  2379370717
# 5              AI ventures   NaN  2022  1242838005
# 6  Agricultural technology   NaN  2017   309478503
# 7  Agricultural technology   NaN  2018   280024054
# 8  Agricultural technology   NaN  2019   502672339
# 9  Agricultural technology   NaN  2020   686735808
#
#    European Union and United Kingdom      China  United States
# 0                           34720055  233168581      404163765
# 1                           30321937  591347599      857474812
# 2                           15388467   93042361      962517568
# 3                            5170265   91954563     1358836062
# 4                         1013359242  258977775      923024967
# 5                           14814431  451988999      641729703
# 6                            7554717   10391318      261846503
# 7                           33194058          0      194254290
# 8                          116117865   18018197      283437548
# 9                           25459779    7959031      624487776

# %%
# Get dataframe summary
df_ai_investment.describe()
# Out:
#        Code         Year         World  European Union and United Kingdom  \
# count   0.0   160.000000  1.600000e+02                       1.600000e+02
# mean    NaN  2019.375000  4.774578e+09                       4.692837e+08
# std     NaN     1.872509  1.414247e+10                       1.459440e+09
# min     NaN  2013.000000  1.481443e+07                       0.000000e+00
# 25%     NaN  2018.000000  6.365509e+08                       3.270104e+07
# 50%     NaN  2019.000000  1.497970e+09                       9.437997e+07
# 75%     NaN  2021.000000  3.361576e+09                       2.599839e+08
# max     NaN  2022.000000  1.253569e+11                       1.250078e+10
#
#               China  United States
# count  1.600000e+02   1.600000e+02
# mean   1.106503e+09   2.637808e+09
# std    3.012095e+09   7.897088e+09
# min    0.000000e+00   0.000000e+00
# 25%    4.276693e+07   2.828651e+08
# 50%    2.342871e+08   6.638859e+08
# 75%    8.462229e+08   1.797541e+09
# max    2.284830e+10   7.339594e+10

# %%
# Let's select the single column "United States"
df_ai_investment["United States"]
# Out:
# 0       404163765
# 1       857474812
# 2       962517568
# 3      1358836062
# 4       923024967
#           ...
# 155     109690663
# 156      28617137
# 157       4502008
# 158      60011724
# 159             0
# Name: United States, Length: 160, dtype: int64

# %%
# Selecting "AI ventures" data year 2018 which is in the 1st row
df_ai_investment.iloc[1]
# Out:
# Entity                               AI ventures
# Code                                         NaN
# Year                                        2018
# World                                 1539250299
# European Union and United Kingdom       30321937
# China                                  591347599
# United States                          857474812
# Name: 1, dtype: object

# %%
# Select value within the "United States" column?
df_ai_investment["United States"][5]
# Out:
# 641729703

# %%
# Get the "United States" data of the 5th row
df_ai_investment[ "United States" ].iloc[4]
# Out:
# 923024967

# %%
# Types of data in each column
for col in df_ai_investment:
    print(col)
    print(type(df_ai_investment[col][0]))
# Out:
# Entity
# <class 'str'>
# Code
# <class 'numpy.float64'>
# Year
# <class 'numpy.int64'>
# World
# <class 'numpy.int64'>
# European Union and United Kingdom
# <class 'numpy.int64'>
# China
# <class 'numpy.int64'>
# United States
# <class 'numpy.int64'>

# %%
# Can also use .dtypes
df_ai_investment.dtypes
# Out:
# Entity                                object
# Code                                 float64
# Year                                   int64
# World                                  int64
# European Union and United Kingdom      int64
# China                                  int64
# United States                          int64
# dtype: object

# %%
# We can see column "code" has NaN values
# Use .isna() to formally check
df_ai_investment["Code"].isna()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 155    True
# 156    True
# 157    True
# 158    True
# 159    True
# Name: Code, Length: 160, dtype: bool

# %%
# Fill NaN values with a certain value
df_ai_investment["Code"] = df_ai_investment["Code"].fillna("N")
df_ai_investment
# Out:
#               Entity Code  Year       World  \
# 0        AI ventures    N  2017   705626292
# 1        AI ventures    N  2018  1539250299
# 2        AI ventures    N  2019  1212544984
# 3        AI ventures    N  2020  1545821073
# 4        AI ventures    N  2021  2379370717
# ..               ...  ...   ...         ...
# 155  Venture capital    N  2018   217600809
# 156  Venture capital    N  2019   106903067
# 157  Venture capital    N  2020   179347432
# 158  Venture capital    N  2021   225784599
# 159  Venture capital    N  2022    14814431
#
#      European Union and United Kingdom      China  United States
# 0                             34720055  233168581      404163765
# 1                             30321937  591347599      857474812
# 2                             15388467   93042361      962517568
# 3                              5170265   91954563     1358836062
# 4                           1013359242  258977775      923024967
# ..                                 ...        ...            ...
# 155                                  0  107910146      109690663
# 156                           26497349          0       28617137
# 157                                  0  124590452        4502008
# 158                                  0          0       60011724
# 159                           14814431          0              0
#
# [160 rows x 7 columns]

# %%
# Removing code column 
# Select specific subset of columns in dataframe using column names list
col_wanted = ["Entity", "Year", "World", "European Union and United Kingdom", "China", "United States"]
df_ai_investment_new = df_ai_investment[col_wanted]
df_ai_investment_new
# Out:
#               Entity  Year       World  European Union and United Kingdom  \
# 0        AI ventures  2017   705626292                           34720055
# 1        AI ventures  2018  1539250299                           30321937
# 2        AI ventures  2019  1212544984                           15388467
# 3        AI ventures  2020  1545821073                            5170265
# 4        AI ventures  2021  2379370717                         1013359242
# ..               ...   ...         ...                                ...
# 155  Venture capital  2018   217600809                                  0
# 156  Venture capital  2019   106903067                           26497349
# 157  Venture capital  2020   179347432                                  0
# 158  Venture capital  2021   225784599                                  0
# 159  Venture capital  2022    14814431                           14814431
#
#          China  United States
# 0    233168581      404163765
# 1    591347599      857474812
# 2     93042361      962517568
# 3     91954563     1358836062
# 4    258977775      923024967
# ..         ...            ...
# 155  107910146      109690663
# 156          0       28617137
# 157  124590452        4502008
# 158          0       60011724
# 159          0              0
#
# [160 rows x 6 columns]

# %%
# We can count the values of the private ai investment entity in the dataframe
df_ai_investment_new["Entity"].value_counts()
# Out:
# Entity
# Total                                            10
# AI ventures                                       6
# Agricultural technology                           6
# Semiconductors                                    6
# Sales enablement                                  6
# Retail                                            6
# Natural Language Processing, customer support     6
# Music and video content                           6
# Medical and healthcare                            6
# Marketing and digital ads                         6
# Legal technology                                  6
# Insurance technology                              6
# Industrial automation                             6
# Human Resources technology                        6
# Geospatial                                        6
# Fitness and wellness                              6
# Financial technology                              6
# Facial recognition                                6
# Entertainment                                     6
# Energy, oil and gas                               6
# Educational technology                            6
# Drones                                            6
# Data management                                   6
# Cybersecurity                                     6
# Augmented or virtual reality                      6
# Venture capital                                   6
# Name: count, dtype: int64

# %%
# We can get the unique entity names
entity = df_ai_investment_new["Entity"].unique()
print(entity)

# And get # of entity present
print(len(entity))

# We can also get number of unique entity this way
n_entity = df_ai_investment_new["Entity"].nunique()
n_entity
# Out:
# ['AI ventures' 'Agricultural technology' 'Augmented or virtual reality'
#  'Cybersecurity' 'Data management' 'Drones' 'Educational technology'
#  'Energy, oil and gas' 'Entertainment' 'Facial recognition'
#  'Financial technology' 'Fitness and wellness' 'Geospatial'
#  'Human Resources technology' 'Industrial automation'
#  'Insurance technology' 'Legal technology' 'Marketing and digital ads'
#  'Medical and healthcare' 'Music and video content'
#  'Natural Language Processing, customer support' 'Retail'
#  'Sales enablement' 'Semiconductors' 'Total' 'Venture capital']
# 26
# 26

# %% [markdown]
# ### Part 2: Calculations and Grouping
#
# #### Start with calculations of data

# %%
# Find Shares of respective regions
region = ["European Union and United Kingdom", "China", "United States"]

# Create function for getting share
def getShare(df, regions, world):
    for reg in regions:
        col_name = "Share of " + reg
        df[col_name] = df[reg]/df[world]*100

# Call function
getShare(df_ai_investment_new, region, "World")

# %%
# Examine
df_ai_investment_new
# Out:
#               Entity  Year       World  European Union and United Kingdom  \
# 0        AI ventures  2017   705626292                           34720055
# 1        AI ventures  2018  1539250299                           30321937
# 2        AI ventures  2019  1212544984                           15388467
# 3        AI ventures  2020  1545821073                            5170265
# 4        AI ventures  2021  2379370717                         1013359242
# ..               ...   ...         ...                                ...
# 155  Venture capital  2018   217600809                                  0
# 156  Venture capital  2019   106903067                           26497349
# 157  Venture capital  2020   179347432                                  0
# 158  Venture capital  2021   225784599                                  0
# 159  Venture capital  2022    14814431                           14814431
#
#          China  United States  Share of European Union and United Kingdom  \
# 0    233168581      404163765                                    4.920459
# 1    591347599      857474812                                    1.969916
# 2     93042361      962517568                                    1.269105
# 3     91954563     1358836062                                    0.334467
# 4    258977775      923024967                                   42.589380
# ..         ...            ...                                         ...
# 155  107910146      109690663                                    0.000000
# 156          0       28617137                                   24.786332
# 157  124590452        4502008                                    0.000000
# 158          0       60011724                                    0.000000
# 159          0              0                                  100.000000
#
#      Share of China  Share of United States
# 0         33.044203               57.277311
# 1         38.417897               55.707302
# 2          7.673312               79.379947
# 3          5.948590               87.903839
# 4         10.884297               38.792819
# ..              ...                     ...
# 155       49.590875               50.409125
# 156        0.000000               26.769239
# 157       69.468768                2.510216
# 158        0.000000               26.579193
# 159        0.000000                0.000000
#
# [160 rows x 9 columns]

# %%
# Df for only the year 2022
# Do so by doing boolean masking
df_ai_investment_2022 = df_ai_investment_new[df_ai_investment_new["Year"] == 2022]
df_ai_investment_2022
# Out:
#                                             Entity  Year        World  \
# 5                                      AI ventures  2022   1242838005
# 11                         Agricultural technology  2022    810137282
# 17                    Augmented or virtual reality  2022   2214330335
# 23                                   Cybersecurity  2022   4978670210
# 29                                 Data management  2022   5423724972
# 35                                          Drones  2022   1745272701
# 41                          Educational technology  2022    344161272
# 47                             Energy, oil and gas  2022   1487149762
# 53                                   Entertainment  2022    804408782
# 59                              Facial recognition  2022     62498395
# 65                            Financial technology  2022   5114007205
# 71                            Fitness and wellness  2022    487005579
# 77                                      Geospatial  2022    661432857
# 83                      Human Resources technology  2022   1506868367
# 89                           Industrial automation  2022   3628084361
# 95                            Insurance technology  2022   1612298318
# 101                               Legal technology  2022    768606509
# 107                      Marketing and digital ads  2022   2824636407
# 113                         Medical and healthcare  2022   5605698104
# 119                        Music and video content  2022   1588582322
# 125  Natural Language Processing, customer support  2022    931708894
# 131                                         Retail  2022   3888940189
# 137                               Sales enablement  2022   2941835680
# 143                                 Semiconductors  2022   1532108942
# 153                                          Total  2022  85055265067
# 159                                Venture capital  2022     14814431
#
#      European Union and United Kingdom        China  United States  \
# 5                             14814431    451988999      641729703
# 11                            76739673     95402811      509921645
# 17                            60016045     13332988     1912898173
# 23                           217439686    992985857     3578690067
# 29                           219221105   1727359990     2894398654
# 35                            39090208     25925254     1483572636
# 41                            95099978     12027466      111497296
# 47                           185258640    319406209      745179209
# 53                           160331685    170547096      431472870
# 59                                   0            0       62498395
# 65                           868080225     30369583     2991720037
# 71                           129626269            0      211475994
# 77                             6343098     27262708      506111231
# 83                          1183301340            0      219437686
# 89                          1528970761    979711647      802103534
# 95                          1193451134            0      360852254
# 101                           56314360     43702571      661033921
# 107                          701624001    811250613     1055013635
# 113                          707457022    235405533     3883317553
# 119                          408435253     28425189     1015177331
# 125                           33783127    122824695      635764264
# 131                         1914569974     13888529     1410866709
# 137                          147968093   1557779673     1039963332
# 143                           11481184    946096889      536568891
# 153                        10217823819  12412402667    43848726664
# 159                           14814431            0              0
#
#      Share of European Union and United Kingdom  Share of China  \
# 5                                      1.191984       36.367491
# 11                                     9.472428       11.776129
# 17                                     2.710347        0.602123
# 23                                     4.367425       19.944801
# 29                                     4.041892       31.848222
# 35                                     2.239777        1.485456
# 41                                    27.632388        3.494718
# 47                                    12.457295       21.477743
# 53                                    19.931618       21.201546
# 59                                     0.000000        0.000000
# 65                                    16.974560        0.593851
# 71                                    26.616999        0.000000
# 77                                     0.958993        4.121765
# 83                                    78.527187        0.000000
# 89                                    42.142646       27.003552
# 95                                    74.021732        0.000000
# 101                                    7.326813        5.685949
# 107                                   24.839445       28.720532
# 113                                   12.620320        4.199397
# 119                                   25.710676        1.789343
# 125                                    3.625932       13.182733
# 131                                   49.231150        0.357129
# 137                                    5.029788       52.952641
# 143                                    0.749371       61.751280
# 153                                   12.013159       14.593338
# 159                                  100.000000        0.000000
#
#      Share of United States
# 5                 51.634219
# 11                62.942622
# 17                86.387209
# 23                71.880440
# 29                53.365513
# 35                85.005205
# 41                32.396817
# 47                50.107879
# 53                53.638508
# 59               100.000000
# 65                58.500505
# 71                43.423731
# 77                76.517401
# 83                14.562499
# 89                22.108183
# 95                22.381234
# 101               86.004205
# 107               37.350423
# 113               69.274468
# 119               63.904610
# 125               68.236363
# 131               36.278951
# 137               35.350830
# 143               35.021589
# 153               51.553219
# 159                0.000000

# %%
# Get maximum entity from United States
max_2022 = df_ai_investment_2022["United States"].max()

# Get minimum entity from United States
min_2022 = df_ai_investment_2022["United States"].min()
print("The maximum entity value is {} and the minimum entity value is {}.".format(max_2022, min_2022))
# Out:
# The maximum entity value is 43848726664 and the minimum entity value is 0.

# %% [markdown]
# It seems there is the row Total is interfering with the result we want.

# %%
# This is another use of boolean masking
df_ai_investment_new = df_ai_investment_new[df_ai_investment_new["Entity"] != "Total"]
df_ai_investment_2022 = df_ai_investment_2022[df_ai_investment_2022["Entity"] != "Total"]

# Get maximum entity from United States
max_2022 = df_ai_investment_2022["United States"].max()

# Get minimum entity from United States
min_2022 = df_ai_investment_2022["United States"].min()
print("The maximum entity value is {} and the minimum entity value is {}.".format(max_2022, min_2022))
# Out:
# The maximum entity value is 3883317553 and the minimum entity value is 0.

# %% [markdown]
# #### Let's get to grouping data!

# %%
# Import new data
df_ai_views = pd.read_csv("data/views-ai-impact-society-next-20-years.csv")
df_ai_views
# Out:
#           Entity Code  Year  Mostly help   Neither  \
# 0    Afghanistan  AFG  2019    33.451640  2.129547
# 1    Afghanistan  AFG  2021    42.600000  0.700000
# 2        Albania  ALB  2019    17.870370  0.740741
# 3        Albania  ALB  2021    21.700000  0.200000
# 4        Algeria  DZA  2019    20.909090  1.000000
# ..           ...  ...   ...          ...       ...
# 233      Vietnam  VNM  2021    59.483616  4.369414
# 234       Zambia  ZMB  2019    24.000000  1.100000
# 235       Zambia  ZMB  2021    27.000000  1.500000
# 236     Zimbabwe  ZWE  2019    48.521255  0.924214
# 237     Zimbabwe  ZWE  2021    33.700000  1.000000
#
#      Refused - help/harm question  \
# 0                             NaN
# 1                             NaN
# 2                        0.092593
# 3                        0.100000
# 4                        0.181818
# ..                            ...
# 233                           NaN
# 234                      0.100000
# 235                      0.100000
# 236                           NaN
# 237                           NaN
#
#      Don't have an opinion, Don't know - help/harm question  Mostly harm
# 0                                            40.638863         23.779947
# 1                                            31.900000         24.800000
# 2                                            32.870370         48.425926
# 3                                            25.500000         52.500000
# 4                                            23.909090         54.000000
# ..                                                 ...               ...
# 233                                          22.244290         13.902681
# 234                                          34.800000         40.000000
# 235                                          33.500000         37.900000
# 236                                          23.382626         27.171904
# 237                                          19.500000         45.800000
#
# [238 rows x 8 columns]

# %%
# Sort by "Mostly help" value
df_sort_help = df_ai_views.sort_values("Mostly help", ascending=False)
df_sort_help
# Out:
#                      Entity Code  Year  Mostly help   Neither  \
# 63                  Finland  FIN  2021    72.266400  0.994036
# 193             South Korea  KOR  2021    69.920320  1.095617
# 192             South Korea  KOR  2019    66.931480  1.489573
# 155                  Norway  NOR  2021    63.800000  0.700000
# 51                  Denmark  DNK  2021    61.700000  0.200000
# ..                      ...  ...   ...          ...       ...
# 148               Nicaragua  NIC  2019    14.444445  1.574074
# 161                Paraguay  PRY  2021    14.185814  0.099900
# 207                Tanzania  TZA  2021    11.700000  0.200000
# 99                  Jamaica  JAM  2021    11.485148  0.396040
# 22   Bosnia and Herzegovina  BIH  2019    10.740741  0.740741
#
#      Refused - help/harm question  \
# 63                            NaN
# 193                      0.199203
# 192                           NaN
# 155                           NaN
# 51                            NaN
# ..                            ...
# 148                      1.111111
# 161                      0.199800
# 207                      0.100000
# 99                       3.564356
# 22                       0.092593
#
#      Don't have an opinion, Don't know - help/harm question  Mostly harm
# 63                                           11.530815         15.208748
# 193                                          14.143426         14.641435
# 192                                          10.625621         20.953327
# 155                                          21.100000         14.400000
# 51                                           22.100000         16.000000
# ..                                                 ...               ...
# 148                                          35.740740         47.129630
# 161                                          35.264736         50.249752
# 207                                          25.300000         62.700000
# 99                                           54.653465         29.900990
# 22                                           24.444445         63.981480
#
# [238 rows x 8 columns]

# %%
# Filter for rows with "Mostly help" > 50 percent
df_sort_help_top = df_sort_help[df_sort_help["Mostly help"] > 60] 

# Get how many occurences accross 2 years
print("There's a total of {} recorded data where views are 'Mostly help'".format(len(df_sort_help_top)))

# See dataframe
df_sort_help_top
# Out:
# There's a total of 9 recorded data where views are 'Mostly help'
#           Entity Code  Year  Mostly help   Neither  \
# 63       Finland  FIN  2021    72.266400  0.994036
# 193  South Korea  KOR  2021    69.920320  1.095617
# 192  South Korea  KOR  2019    66.931480  1.489573
# 155       Norway  NOR  2021    63.800000  0.700000
# 51       Denmark  DNK  2021    61.700000  0.200000
# 101        Japan  JPN  2021    61.485150  5.049505
# 39         China  CHN  2021    61.000000  4.314286
# 199       Sweden  SWE  2021    60.739260  0.299700
# 100        Japan  JPN  2019    60.474308  5.335968
#
#      Refused - help/harm question  \
# 63                            NaN
# 193                      0.199203
# 192                           NaN
# 155                           NaN
# 51                            NaN
# 101                           NaN
# 39                       0.057143
# 199                           NaN
# 100                           NaN
#
#      Don't have an opinion, Don't know - help/harm question  Mostly harm
# 63                                           11.530815         15.208748
# 193                                          14.143426         14.641435
# 192                                          10.625621         20.953327
# 155                                          21.100000         14.400000
# 51                                           22.100000         16.000000
# 101                                          20.297030         13.168317
# 39                                           21.742857         12.885715
# 199                                          26.473526         12.487513
# 100                                          16.798418         17.391304

# %%
# Find which view category have highest share
# Select the relevant columns for comparison
columns_to_compare = ["Mostly help", "Neither", "Refused - help/harm question", "Don't have an opinion, Don't know - help/harm question", "Mostly harm"]

# Create a new column "Highest View" with the column name having the maximum value
df_ai_views["Highest View"] = df_ai_views[columns_to_compare].idxmax(axis=1) # we can use idxmax here with axis=1 meaning columns
df_ai_views
# Out:
#           Entity Code  Year  Mostly help   Neither  \
# 0    Afghanistan  AFG  2019    33.451640  2.129547
# 1    Afghanistan  AFG  2021    42.600000  0.700000
# 2        Albania  ALB  2019    17.870370  0.740741
# 3        Albania  ALB  2021    21.700000  0.200000
# 4        Algeria  DZA  2019    20.909090  1.000000
# ..           ...  ...   ...          ...       ...
# 233      Vietnam  VNM  2021    59.483616  4.369414
# 234       Zambia  ZMB  2019    24.000000  1.100000
# 235       Zambia  ZMB  2021    27.000000  1.500000
# 236     Zimbabwe  ZWE  2019    48.521255  0.924214
# 237     Zimbabwe  ZWE  2021    33.700000  1.000000
#
#      Refused - help/harm question  \
# 0                             NaN
# 1                             NaN
# 2                        0.092593
# 3                        0.100000
# 4                        0.181818
# ..                            ...
# 233                           NaN
# 234                      0.100000
# 235                      0.100000
# 236                           NaN
# 237                           NaN
#
#      Don't have an opinion, Don't know - help/harm question  Mostly harm  \
# 0                                            40.638863         23.779947
# 1                                            31.900000         24.800000
# 2                                            32.870370         48.425926
# 3                                            25.500000         52.500000
# 4                                            23.909090         54.000000
# ..                                                 ...               ...
# 233                                          22.244290         13.902681
# 234                                          34.800000         40.000000
# 235                                          33.500000         37.900000
# 236                                          23.382626         27.171904
# 237                                          19.500000         45.800000
#
#                                           Highest View
# 0    Don't have an opinion, Don't know - help/harm ...
# 1                                          Mostly help
# 2                                          Mostly harm
# 3                                          Mostly harm
# 4                                          Mostly harm
# ..                                                 ...
# 233                                        Mostly help
# 234                                        Mostly harm
# 235                                        Mostly harm
# 236                                        Mostly help
# 237                                        Mostly harm
#
# [238 rows x 9 columns]

# %%
# How can we look at each year's total count of each view category?
# Use groupby to group by the year, then use value_counts() on "Highest View"

df_all_views = df_ai_views.groupby("Year")["Highest View"].value_counts()
df_all_views # result is a series
# Out:
# Year  Highest View
# 2019  Mostly harm                                               66
#       Mostly help                                               42
#       Don't have an opinion, Don't know - help/harm question    11
# 2021  Mostly help                                               52
#       Mostly harm                                               49
#       Don't have an opinion, Don't know - help/harm question    18
# Name: count, dtype: int64

# %%
# Look at year 2021 only
df_all_views[2021]
# Out:
# Highest View
# Mostly help                                               52
# Mostly harm                                               49
# Don't have an opinion, Don't know - help/harm question    18
# Name: count, dtype: int64

# %%
# We can also do the same thing with using .agg() which is a method that allows aggregation operations
# Group by "Year" and "Highest View" and find the most frequent "Highest View" category
df_all_views_2 = df_ai_views.groupby(["Year","Highest View"]).agg(view_count = ("Highest View", "count"))
df_all_views_2 # result is a dataframe
# Out:
#                                                          view_count
# Year Highest View
# 2019 Don't have an opinion, Don't know - help/harm q...          11
#      Mostly harm                                                 66
#      Mostly help                                                 42
# 2021 Don't have an opinion, Don't know - help/harm q...          18
#      Mostly harm                                                 49
#      Mostly help                                                 52

# %% [markdown]
# Let's learn pivot table now!

# %%
# Create a pivot table to count occurrences of each category in "Highest View" for each year
df_all_views_3 = df_ai_views.pivot_table(values="Entity", index="Year", columns="Highest View", aggfunc="count", fill_value=0)
df_all_views_3 # result is dataframe
# Out:
# Highest View  Don't have an opinion, Don't know - help/harm question  \
# Year
# 2019                                                         11
# 2021                                                         18
#
# Highest View  Mostly harm  Mostly help
# Year
# 2019                   66           42
# 2021                   49           52

# %%
# Use .loc to select a row
df_all_views_3.loc[2019]
# Out:
# Highest View
# Don't have an opinion, Don't know - help/harm question    11
# Mostly harm                                               66
# Mostly help                                               42
# Name: 2019, dtype: int64

# %% [markdown]
# #### Now, we're equipped with the basics of working with datasets!
